# %% [markdown]
# # Naives Bayes Classifier(NLP)

# %% [raw]
# Naives Bayes Classifier (NLP): It is supervised mL algorithm  based on Bayes theorem (probability).
# Classification Model(Multiclassification): Text Classification
# Gaussian NB
#
# Bayes Theorem:
# p(A/B)=P(A).P(B/A/(Ptotal))

# %% [raw]
# NLP:
# Natural Language Processing it is a field of AI that hepls computer to undertasnd interpret to genrate human language

# %%
# Importing Libraries
import pandas as pd

# %%
df=pd.read_csv(r'D:\ExcelR Data Science\July\July 16\iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# Use case

# %% [raw]
# We are classifing different species of iris flower datase bsed on sepal length and width using Naives Bayes Theorem
# setosa(small)
# virginica(medium)
# versicolor(large)

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
# Feature Extraction
df.iloc[:,0:4]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
x=df.loc[:,['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]
x
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df['variety']
y
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: variety, Length: 150, dtype: object

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test,=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
from sklearn.naive_bayes import GaussianNB
model1=GaussianNB()
model1.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.naive_bayes import GaussianNB
model1=GaussianNB()
model1.fit(x_test,y_test)
# Out:
# GaussianNB()

# %%
y_pred=model1.predict(x_test)
y_pred
# Out:
# array(['Setosa', 'Versicolor', 'Versicolor', 'Setosa', 'Virginica',
#        'Versicolor', 'Virginica', 'Setosa', 'Setosa', 'Virginica',
#        'Versicolor', 'Setosa', 'Virginica', 'Versicolor', 'Versicolor',
#        'Setosa', 'Versicolor', 'Versicolor', 'Setosa', 'Setosa',
#        'Versicolor', 'Versicolor', 'Versicolor', 'Setosa', 'Virginica',
#        'Versicolor', 'Setosa', 'Setosa', 'Versicolor', 'Virginica'],
#       dtype='<U10')

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  0,  6]], dtype=int64)

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, cmap='viridis',
            xticklabels=['setosa', 'virginica', 'versicolor'],
            yticklabels=['setosa', 'virginica', 'versicolor'])
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        11
#   Versicolor       1.00      1.00      1.00        13
#    Virginica       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [raw]
# Infer 100 percent accuracy : Excellent model
# Accuracy Score: 100 Percent
# F1 sore: 100 Percent
# Setosa  --36 Percent
# Versicolor --43 Percent
# Virginica -- 20 Percent

# %%
print(11/30) # Setosa  --36 Percent 

print(13/30) # Versicolor --43 Percent

print(6/30) # Virginica -- 20 Percent
# Out:
# 0.36666666666666664
# 0.43333333333333335
# 0.2
